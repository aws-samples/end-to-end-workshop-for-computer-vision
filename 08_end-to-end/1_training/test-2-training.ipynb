# %%
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
sess = sagemaker.Session()

default_bucket = sess.default_bucket() # or use your own custom bucket name
account = sess.account_id()
base_job_prefix = 'BirdEnd2End'
region = sagemaker.Session().boto_region_name

# %%
from sagemaker.tensorflow import TensorFlow

from sagemaker.debugger import (ProfilerConfig,
                                FrameworkProfile,
                                CollectionConfig,
                                DebuggerHookConfig,
                                DetailedProfilingConfig, 
                                DataloaderProfilingConfig, 
                                PythonProfilingConfig,
                                Rule,
                                PythonProfiler,
                                cProfileTimer,
                                ProfilerRule,
                                rule_configs)

from sagemaker.inputs import TrainingInput


TF_FRAMEWORK_VERSION = '2.1'

# %%
# Location in S3 where the debugger output will be stored is mentioned in the previous step

# Set the profile config for both system and framework metrics
profiler_config = ProfilerConfig(
    system_monitor_interval_millis = 500,
    framework_profile_params = FrameworkProfile(
        detailed_profiling_config = DetailedProfilingConfig(
            start_step = 5, 
            num_steps = 10
        ),
        dataloader_profiling_config = DataloaderProfilingConfig(
            start_step = 7, 
            num_steps = 10
        ),
        python_profiling_config = PythonProfilingConfig(
            start_step = 9, 
            num_steps = 10,
            python_profiler = PythonProfiler.CPROFILE, 
            cprofile_timer = cProfileTimer.TOTAL_TIME
        )
    )
)

# Set the debugger hook config to save tensors
debugger_hook_config = DebuggerHookConfig(
    collection_configs = [
        CollectionConfig(name = 'weights'),
        CollectionConfig(name = 'gradients')
    ]
)

# Set the rules to analyze tensors emitted during training
# These specific set of rules will inspect the overall training performance and progress of the model
rules=[
    ProfilerRule.sagemaker(rule_configs.ProfilerReport()),
#     Rule.sagemaker(rule_configs.loss_not_decreasing()),
#     Rule.sagemaker(rule_configs.overfit()),
]

# %%
import uuid


checkpoint_s3_uri = f's3://{default_bucket}/{base_job_prefix}/checkpoints/{uuid.uuid4()}'

model_path = f"s3://{default_bucket}/{base_job_prefix}"

instance_type  = 'ml.p3.2xlarge'#'ml.p3.16xlarge'#
instance_count = 1

gpus_per_host = 1

hyperparameters = {'lr':                 0.00012367461028516715, #0.000019,
                   'batch_size':         8,
                   'epochs':             38, #36, 
                   'dropout':            0.7459862089753134, #0.76,
                   'data_dir':           '/opt/ml/input/data'}
    
metric_definitions = [{'Name': 'loss',      'Regex': 'loss: ([0-9\\.]+)'},
                      {'Name': 'acc',       'Regex': 'accuracy: ([0-9\\.]+)'},
                      {'Name': 'val_loss',  'Regex': 'val_loss: ([0-9\\.]+)'},
                      {'Name': 'val_acc',   'Regex': 'val_accuracy: ([0-9\\.]+)'}]

distribution = {'parameter_server': {'enabled': False}}

estimator = TensorFlow(entry_point='train.py',
                       source_dir='pipeline/code',
                       instance_type=instance_type,
                       instance_count=instance_count,
                       distribution=distribution,
                       output_path=model_path,
                       hyperparameters=hyperparameters,
                       metric_definitions=metric_definitions,
                       role=role,
                       framework_version=TF_FRAMEWORK_VERSION, 
                       py_version='py3',
                       base_job_name=f"{base_job_prefix}-debugger",
                       profiler_config=profiler_config,
                       debugger_hook_config=debugger_hook_config,
                       rules=rules,
                       input_mode='Pipe',
                       script_mode=True)

# %%
# Set the training container related parameters

output_s3_uri = f's3://{default_bucket}/{base_job_prefix}/scriptprocessor/output/preprocess'

s3_train = output_s3_uri +'/train'
s3_valid = output_s3_uri +'/valid'

DISTRIBUTION_MODE = 'FullyReplicated'

# output_s3_uri is the output from previous process.

train_in = TrainingInput(s3_data=s3_train, distribution=DISTRIBUTION_MODE)
val_in   = TrainingInput(s3_data=s3_valid, distribution=DISTRIBUTION_MODE)

inputs = {'train':train_in, 'valid': val_in}

estimator.fit(inputs)
# Out:
# 2022-03-17 20:19:29 Starting - Starting the training job...ProfilerReport: InProgress
# ...
# 2022-03-17 20:20:12 Starting - Preparing the instances for training......
# 2022-03-17 20:21:18 Downloading - Downloading input data...
# 2022-03-17 20:21:53 Training - Downloading the training image............
# 2022-03-17 20:23:54 Training - Training image download completed. Training in progress..2022-03-17 20:24:00,682 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-03-17 20:24:01,246 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": false
#     },
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "valid": "/opt/ml/input/data/valid"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 8,
#         "data_dir": "/opt/ml/input/data",
#         "dropout": 0.7459862089753134,
#         "epochs": 38,
#         "lr": 0.00012367461028516715,
#         "model_dir": "s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "valid": {
#             "TrainingInputMode": "Pipe",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "BirdEnd2End-debugger-2022-03-17-20-19-28-892",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-987720697751/BirdEnd2End-debugger-2022-03-17-20-19-28-892/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":8,"data_dir":"/opt/ml/input/data","dropout":0.7459862089753134,"epochs":38,"lr":0.00012367461028516715,"model_dir":"s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":false}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"valid":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","valid"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-987720697751/BirdEnd2End-debugger-2022-03-17-20-19-28-892/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":false},"channel_input_dirs":{"train":"/opt/ml/input/data/train","valid":"/opt/ml/input/data/valid"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":8,"data_dir":"/opt/ml/input/data","dropout":0.7459862089753134,"epochs":38,"lr":0.00012367461028516715,"model_dir":"s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"},"valid":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"Pipe"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"BirdEnd2End-debugger-2022-03-17-20-19-28-892","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-987720697751/BirdEnd2End-debugger-2022-03-17-20-19-28-892/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","8","--data_dir","/opt/ml/input/data","--dropout","0.7459862089753134","--epochs","38","--lr","0.00012367461028516715","--model_dir","s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALID=/opt/ml/input/data/valid
# SM_HP_BATCH_SIZE=8
# SM_HP_DATA_DIR=/opt/ml/input/data
# SM_HP_DROPOUT=0.7459862089753134
# SM_HP_EPOCHS=38
# SM_HP_LR=0.00012367461028516715
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.6 train.py --batch_size 8 --data_dir /opt/ml/input/data --dropout 0.7459862089753134 --epochs 38 --lr 0.00012367461028516715 --model_dir s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model
# TF version: 2.1.3
# Keras version: 2.3.0-tf
# Executing the main() function...
# Parsing command-line arguments...
# Completed parsing command-line arguments.
# args: Namespace(batch_size=8, checkpoint_path='/opt/ml/checkpoints', current_host='algo-1', data_config={'train': {'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated', 'TrainingInputMode': 'Pipe'}, 'valid': {'RecordWrapperType': 'None', 'S3DistributionType': 'FullyReplicated', 'TrainingInputMode': 'Pipe'}}, dropout=0.7459862089753134, fine_tuning_epochs=30, fine_tuning_lr=1e-05, hosts=['algo-1'], initial_epochs=5, initial_lr=0.0001, model_dir='s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-20-19-28-892/model', num_fully_connected_layers=1, s3_checkpoint_path='', train='/opt/ml/input/data/train', valid='/opt/ml/input/data/valid')
# Load TFRecord files ...
# Downloading data from https://github.com/JonathanCMitchell/mobilenet_v2_keras/releases/download/v1.1/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# #015   8192/9406464 [..............................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0152400256/9406464 [======>.......................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0152539520/9406464 [=======>......................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0154202496/9406464 [============>.................] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0155398528/9406464 [================>.............] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0156594560/9406464 [====================>.........] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0157790592/9406464 [=======================>......] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0158396800/9406464 [=========================>....] - ETA: 0s#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0159412608/9406464 [==============================] - 0s 0us/step
# Beginning training...
# Batch size: 8, Train Steps: 41, Val Steps: 12
# [2022-03-17 20:24:10.844 ip-10-0-166-201.us-west-2.compute.internal:34 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-03-17 20:24:10.845 ip-10-0-166-201.us-west-2.compute.internal:34 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-03-17 20:24:10.845 ip-10-0-166-201.us-west-2.compute.internal:34 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2022-03-17 20:24:10.846 ip-10-0-166-201.us-west-2.compute.internal:34 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# Train for 41 steps, validate for 12 steps
# Epoch 1/5
# [2022-03-17 20:24:10.948 ip-10-0-166-201.us-west-2.compute.internal:34 INFO hook.py:398] Monitoring the collections: losses, metrics, weights, gradients, sm_metrics
# 41/41 - 14s - loss: 2.8790 - accuracy: 0.4695 - val_loss: 0.4488 - val_accuracy: 0.8438
# Epoch 2/5
# 41/41 - 4s - loss: 0.8140 - accuracy: 0.7988 - val_loss: 0.3775 - val_accuracy: 0.8958
# Epoch 3/5
# 41/41 - 3s - loss: 0.3121 - accuracy: 0.9146 - val_loss: 0.3569 - val_accuracy: 0.8854
# Epoch 4/5
# 41/41 - 3s - loss: 0.1900 - accuracy: 0.9421 - val_loss: 0.2769 - val_accuracy: 0.9062
# Epoch 5/5
# 41/41 - 3s - loss: 0.1498 - accuracy: 0.9482 - val_loss: 0.2170 - val_accuracy: 0.9375
# Beginning training...
# Batch size: 8, Train Steps: 41, Val Steps: 12
# Train for 41 steps, validate for 12 steps
# Epoch 1/30
# Epoch 00001: saving model to /opt/ml/checkpoints/checkpoint-1.ckpt
# 41/41 - 35s - loss: 0.9495 - accuracy: 0.7073 - val_loss: 0.1943 - val_accuracy: 0.9375
# Epoch 2/30
# Epoch 00002: saving model to /opt/ml/checkpoints/checkpoint-2.ckpt
# 41/41 - 27s - loss: 0.8885 - accuracy: 0.7134 - val_loss: 0.1829 - val_accuracy: 0.9375
# Epoch 3/30
# Epoch 00003: saving model to /opt/ml/checkpoints/checkpoint-3.ckpt
# 41/41 - 27s - loss: 0.6178 - accuracy: 0.8140 - val_loss: 0.1745 - val_accuracy: 0.9479
# Epoch 4/30
# Epoch 00004: saving model to /opt/ml/checkpoints/checkpoint-4.ckpt
# 41/41 - 27s - loss: 0.5627 - accuracy: 0.8110 - val_loss: 0.1801 - val_accuracy: 0.9479
# Epoch 5/30
# Epoch 00005: saving model to /opt/ml/checkpoints/checkpoint-5.ckpt
# 41/41 - 27s - loss: 0.4902 - accuracy: 0.8293 - val_loss: 0.1682 - val_accuracy: 0.9479
# Epoch 6/30
# Epoch 00006: saving model to /opt/ml/checkpoints/checkpoint-6.ckpt
# 41/41 - 29s - loss: 0.4775 - accuracy: 0.8598 - val_loss: 0.1687 - val_accuracy: 0.9479
# Epoch 7/30
# Epoch 00007: saving model to /opt/ml/checkpoints/checkpoint-7.ckpt
# 41/41 - 27s - loss: 0.5574 - accuracy: 0.8506 - val_loss: 0.1663 - val_accuracy: 0.9479
# Epoch 8/30
# Epoch 00008: saving model to /opt/ml/checkpoints/checkpoint-8.ckpt
# 41/41 - 29s - loss: 0.5076 - accuracy: 0.8476 - val_loss: 0.1635 - val_accuracy: 0.9479
# Epoch 9/30
# Epoch 00009: saving model to /opt/ml/checkpoints/checkpoint-9.ckpt
# 41/41 - 27s - loss: 0.3057 - accuracy: 0.8994 - val_loss: 0.1633 - val_accuracy: 0.9479
# Epoch 10/30
# Epoch 00010: saving model to /opt/ml/checkpoints/checkpoint-10.ckpt
# 41/41 - 28s - loss: 0.3939 - accuracy: 0.8659 - val_loss: 0.1652 - val_accuracy: 0.9479
# Epoch 11/30
# Epoch 00011: saving model to /opt/ml/checkpoints/checkpoint-11.ckpt
# 41/41 - 27s - loss: 0.3366 - accuracy: 0.8750 - val_loss: 0.1572 - val_accuracy: 0.9479
# Epoch 12/30
# Epoch 00012: saving model to /opt/ml/checkpoints/checkpoint-12.ckpt
# 41/41 - 28s - loss: 0.2894 - accuracy: 0.8933 - val_loss: 0.1538 - val_accuracy: 0.9479
# Epoch 13/30
# Epoch 00013: saving model to /opt/ml/checkpoints/checkpoint-13.ckpt
# 41/41 - 29s - loss: 0.3210 - accuracy: 0.8994 - val_loss: 0.1517 - val_accuracy: 0.9479
# Epoch 14/30
# Epoch 00014: saving model to /opt/ml/checkpoints/checkpoint-14.ckpt
# 41/41 - 27s - loss: 0.3243 - accuracy: 0.8902 - val_loss: 0.1536 - val_accuracy: 0.9479
# Epoch 15/30
# Epoch 00015: saving model to /opt/ml/checkpoints/checkpoint-15.ckpt
# 41/41 - 28s - loss: 0.2221 - accuracy: 0.9146 - val_loss: 0.1554 - val_accuracy: 0.9479
# Epoch 16/30
# Epoch 00016: saving model to /opt/ml/checkpoints/checkpoint-16.ckpt
# 41/41 - 28s - loss: 0.2079 - accuracy: 0.9299 - val_loss: 0.1629 - val_accuracy: 0.9479
# Epoch 17/30
# Epoch 00017: saving model to /opt/ml/checkpoints/checkpoint-17.ckpt
# 41/41 - 28s - loss: 0.3057 - accuracy: 0.8933 - val_loss: 0.1597 - val_accuracy: 0.9479
# Epoch 18/30
# Epoch 00018: saving model to /opt/ml/checkpoints/checkpoint-18.ckpt
# 41/41 - 28s - loss: 0.2145 - accuracy: 0.9177 - val_loss: 0.1614 - val_accuracy: 0.9479
# Epoch 19/30
# Epoch 00019: saving model to /opt/ml/checkpoints/checkpoint-19.ckpt
# 41/41 - 28s - loss: 0.2106 - accuracy: 0.9238 - val_loss: 0.1623 - val_accuracy: 0.9479
# Epoch 20/30
# Epoch 00020: saving model to /opt/ml/checkpoints/checkpoint-20.ckpt
# 41/41 - 30s - loss: 0.2289 - accuracy: 0.9360 - val_loss: 0.1618 - val_accuracy: 0.9479
# Epoch 21/30
# Epoch 00021: saving model to /opt/ml/checkpoints/checkpoint-21.ckpt
# 41/41 - 27s - loss: 0.2680 - accuracy: 0.9085 - val_loss: 0.1531 - val_accuracy: 0.9479
# Epoch 22/30
# Epoch 00022: saving model to /opt/ml/checkpoints/checkpoint-22.ckpt
# 41/41 - 28s - loss: 0.1945 - accuracy: 0.9329 - val_loss: 0.1552 - val_accuracy: 0.9479
# Epoch 23/30
# Epoch 00023: saving model to /opt/ml/checkpoints/checkpoint-23.ckpt
# 41/41 - 28s - loss: 0.1762 - accuracy: 0.9451 - val_loss: 0.1583 - val_accuracy: 0.9479
# Epoch 24/30
# Epoch 00024: saving model to /opt/ml/checkpoints/checkpoint-24.ckpt
# 41/41 - 28s - loss: 0.2212 - accuracy: 0.9238 - val_loss: 0.1607 - val_accuracy: 0.9479
# Epoch 25/30
# Epoch 00025: saving model to /opt/ml/checkpoints/checkpoint-25.ckpt
# 41/41 - 29s - loss: 0.2016 - accuracy: 0.9299 - val_loss: 0.1611 - val_accuracy: 0.9479
# Epoch 26/30
# Epoch 00026: saving model to /opt/ml/checkpoints/checkpoint-26.ckpt
# 41/41 - 28s - loss: 0.1843 - accuracy: 0.9390 - val_loss: 0.1553 - val_accuracy: 0.9479
# Epoch 27/30
# Epoch 00027: saving model to /opt/ml/checkpoints/checkpoint-27.ckpt
# 41/41 - 29s - loss: 0.1279 - accuracy: 0.9543 - val_loss: 0.1553 - val_accuracy: 0.9479
# Epoch 28/30
# Epoch 00028: saving model to /opt/ml/checkpoints/checkpoint-28.ckpt
# 41/41 - 28s - loss: 0.1821 - accuracy: 0.9451 - val_loss: 0.1534 - val_accuracy: 0.9479
# Epoch 29/30
# Epoch 00029: saving model to /opt/ml/checkpoints/checkpoint-29.ckpt
# 41/41 - 28s - loss: 0.1088 - accuracy: 0.9604 - val_loss: 0.1533 - val_accuracy: 0.9479
# Epoch 30/30
# Epoch 00030: saving model to /opt/ml/checkpoints/checkpoint-30.ckpt
# 41/41 - 28s - loss: 0.1223 - accuracy: 0.9604 - val_loss: 0.1533 - val_accuracy: 0.9479
# Save the base model ...
# Saving model to /opt/ml/model...
# ...DONE saving model!
# Complete the model training ...
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 2022-03-17 20:24:10.892183: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.822516). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.822516). Check your callbacks.
# 2022-03-17 20:24:20.402461: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:Method (on_test_batch_end) is slow compared to the batch update (0.883338). Check your callbacks.
# WARNING:tensorflow:Method (on_test_batch_end) is slow compared to the batch update (0.883338). Check your callbacks.
# 2022-03-17 20:24:25.508639: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2022-03-17 20:24:28.994528: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2022-03-17 20:24:32.379945: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2022-03-17 20:24:35.679387: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2022-03-17 20:24:39.464973: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.745986 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 2022-03-17 20:24:46.691407: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 2022-03-17 20:25:01.163982: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2022-03-17 20:39:13,370 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-1.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-1.ckpt/assets
# 2022-03-17 20:25:15.440616: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-2.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-2.ckpt/assets
# 2022-03-17 20:25:42.624324: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-3.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-3.ckpt/assets
# 2022-03-17 20:26:09.738935: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-4.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-4.ckpt/assets
# 2022-03-17 20:26:36.885112: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-5.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-5.ckpt/assets
# 2022-03-17 20:27:04.154873: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-6.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-6.ckpt/assets
# 2022-03-17 20:27:33.041416: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-7.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-7.ckpt/assets
# 2022-03-17 20:28:02.049618: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-8.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-8.ckpt/assets
# 2022-03-17 20:28:29.651125: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-9.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-9.ckpt/assets
# 2022-03-17 20:28:57.066156: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-10.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-10.ckpt/assets
# 2022-03-17 20:29:25.022955: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-11.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-11.ckpt/assets
# 2022-03-17 20:29:52.173227: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-12.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-12.ckpt/assets
# 2022-03-17 20:30:20.411697: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-13.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-13.ckpt/assets
# 2022-03-17 20:30:49.408076: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-14.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-14.ckpt/assets
# 2022-03-17 20:31:16.870361: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-15.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-15.ckpt/assets
# 2022-03-17 20:31:44.562409: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-16.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-16.ckpt/assets
# 2022-03-17 20:32:12.330832: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-17.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-17.ckpt/assets
# 2022-03-17 20:32:40.258312: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-18.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-18.ckpt/assets
# 2022-03-17 20:33:08.174555: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-19.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-19.ckpt/assets
# 2022-03-17 20:33:37.666857: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-20.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-20.ckpt/assets
# 2022-03-17 20:34:05.801698: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-21.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-21.ckpt/assets
# 2022-03-17 20:34:33.232575: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-22.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-22.ckpt/assets
# 2022-03-17 20:35:01.043203: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-23.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-23.ckpt/assets
# 2022-03-17 20:35:29.333363: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-24.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-24.ckpt/assets
# 2022-03-17 20:35:57.316811: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-25.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-25.ckpt/assets
# 2022-03-17 20:36:25.889905: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-26.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-26.ckpt/assets
# 2022-03-17 20:36:53.958987: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-27.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-27.ckpt/assets
# 2022-03-17 20:37:22.511359: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-28.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-28.ckpt/assets
# 2022-03-17 20:37:50.630877: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-29.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-29.ckpt/assets
# 2022-03-17 20:38:18.805818: W tensorflow/core/framework/dataset.cc:392] Input of PipeModeDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-30.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/checkpoints/checkpoint-30.ckpt/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/1/assets
#
# 2022-03-17 20:39:38 Uploading - Uploading generated training model
# 2022-03-17 20:40:38 Completed - Training job completed
# Training seconds: 1152
# Billable seconds: 1152

# %%
training_job_name = estimator.latest_training_job.name

print(f"model artifacts file is uploaded here: {model_path}/{training_job_name}/output ========")
# Out:
# model artifacts file is uploaded here: s3://sagemaker-us-west-2-987720697751/BirdEnd2End/BirdEnd2End-debugger-2022-03-17-04-33-10-008/output ========

# %% [markdown]
# ## Tuning Job

# %%
estimator2 = TensorFlow(entry_point='train.py',
                       source_dir='pipeline/code',
                       instance_type=instance_type,
                       instance_count=instance_count,
                       distribution=distribution,
                       output_path=model_path,
                       hyperparameters=hyperparameters,
                       metric_definitions=metric_definitions,
                       role=role,
                       framework_version=TF_FRAMEWORK_VERSION, 
                       py_version='py3',
                       base_job_name=base_job_prefix,
                       input_mode='Pipe',
                       script_mode=True)

# %%
from sagemaker.tuner import ContinuousParameter, IntegerParameter, HyperparameterTuner

hyperparameter_ranges = {
    'epochs': IntegerParameter(30, 40),
    'dropout': ContinuousParameter(0.5, 0.8),
    'lr': ContinuousParameter(0.00001, 0.001)}

objective_metric_name = 'val_acc'
objective_type = 'Maximize'

# %%
tuner = HyperparameterTuner(estimator2,
                        objective_metric_name,
                        hyperparameter_ranges,
                        metric_definitions,
                        max_jobs=2,
                        max_parallel_jobs=2,
                        objective_type=objective_type,
                        base_tuning_job_name=f"{base_job_prefix}-tuning")

tuner.fit(inputs)
# Out:
# ....................................................................................................................................................................................................................................................................................................!
